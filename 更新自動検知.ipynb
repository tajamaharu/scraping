# %% [markdown]
# <a href="https://colab.research.google.com/github/tajamaharu/scraping/blob/main/%E6%9B%B4%E6%96%B0%E8%87%AA%E5%8B%95%E6%A4%9C%E7%9F%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url ="https://scraping.official.ec/items/40792454"
res =requests.get(url)
res.text
# Out:
# '<!doctype html>\n<html cot="" lang="ja">\n<head>\n\t<link rel="stylesheet" type="text/css" href="/asset/shop/BASEshop-c1008465933ef92e4522.css?1626856880"/>\n    <meta name="viewport" content="viewport-fit=cover, width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n    <meta charset="utf-8">\n<meta name="copyright" content="BASE">\n<title>YouTubeコンサルティング | いまにゅのECサイト</title>\n<link rel=\'icon\' type=\'image/png\' href=\'//static.thebase.in/favicon.png\' />\n<link rel=\'apple-touch-icon\' sizes=\'180x180\' href=\'//static.thebase.in/apple-touch-icon.png\' />\n<link rel=\'apple-touch-icon-precomposed\' href=\'//static.thebase.in/apple-touch-icon.png\' />\n<link rel=\'canonical\' href=\'https://scraping.official.ec/items/40792454\' />\n<meta name="description" content="YouTubeチャンネル運営に関してのコンサルティングを行います。中々伸びずの状況が続いていた私のチャンネルですが、直近は月次5000人以上のペースで増加するまでになりました。試行錯誤の末、溜まってきたノウハウがあります。そのノウハウを元に、大枠の部分から細かな部分までアドバイスを行います。教育系チャンネルは得意領域です。※チャンネル登録者数は2万6千人（2021年3月現在）" />\n
# ...

# %%
soup=BeautifulSoup(res.text, "html.parser")
soup

# %%
new_elem = str(soup.select(".item-detail_soldOut_a1dc2e83"))
new_elem
# Out:
# '[<p class="item-detail_soldOut_a1dc2e83">SOLD OUT</p>, <p class="item-detail_soldOut_a1dc2e83">SOLD OUT</p>]'

# %%
try:
    with open("old_elem.txt") as f:
        old_elem = f.read()
except:
    old_elem =""

# %%
if new_elem == old_elem:
    print("変化なし")
else:
    with open("old_elem.txt", "w") as f:
        f.write(new_elem)
    print("webページが変更されました")
# Out:
# webページが変更されました

# %%
def detect_updates():

    url ="https://scraping.official.ec/items/40792454"
    res =requests.get(url)
    soup=BeautifulSoup(res.text, "html.parser")
    new_elem = str(soup.select(".item-detail_soldOut_a1dc2e83"))
    try:
        with open("old_elem.txt") as f:
            old_elem = f.read()
    except:
        old_elem =""
    if new_elem == old_elem:
        print("変化なし")
        return False
    else:
        with open("old_elem.txt", "w") as f:
            f.write(new_elem)
        print("webページが変更されました")
        return True

# %%
detect_updates()
# Out:
# 変化なし
# False
